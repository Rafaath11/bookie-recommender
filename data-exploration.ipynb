# %% [markdown]
# Check the path by pasting it into a terminal using cd and then ls or dir to check the elements that are present in there.

# %%
# We import this from kaggle via kagglehub.
import kagglehub

# Download latest version
path = kagglehub.dataset_download("dylanjcastillo/7k-books-with-metadata")

print("Path to dataset files:", path)
# Out:
# Path to dataset files: C:\Users\LENOVO\.cache\kagglehub\datasets\dylanjcastillo\7k-books-with-metadata\versions\3

# %%
# Since we have the data we can read it with pandas!!
import pandas as pd

# %%
books = pd.read_csv(f"{path}/books.csv")

# %%
# Pandas dataframe.
# as we can see - THE data is distinct.
# In the below data we have a few missing elements, and at categories we have 567 distinct(unique) categories. and a few descriptions are missing, we need to clean up the data.

books
# Out:
#              isbn13      isbn10                      title  \
# 0     9780002005883  0002005883                     Gilead
# 1     9780002261982  0002261987               Spider's Web
# 2     9780006163831  0006163831               The One Tree
# 3     9780006178736  0006178731             Rage of angels
# 4     9780006280897  0006280897             The Four Loves
# ...             ...         ...                        ...
# 6805  9788185300535  8185300534                  I Am that
# 6806  9788185944609  8185944601       Secrets Of The Heart
# 6807  9788445074879  8445074873             Fahrenheit 451
# 6808  9789027712059  9027712050   The Berlin Phenomenology
# 6809  9789042003408  9042003405  'I'm Telling You Stories'
#
#                                             subtitle  \
# 0                                                NaN
# 1                                            A Novel
# 2                                                NaN
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ax = plt.axes() # Setting up canvas
sns.heatmap(books.isna().transpose(), cbar=False, ax=ax)

plt.xlabel("columns")
plt.ylabel("Missing Values")

plt.show()

# %%
import numpy as np

books["missing_description"] = np.where(books['description'].isna(), 1,0)
books["age_of_book"] = 2024 - books["published_year"]

# %%
columns_of_interest = ["num_pages", "age_of_book", "missing_description", "average_rating"]

correlation_matrix = books[columns_of_interest].corr(method="spearman")

sns.set_theme(style="white")
plt.figure(figsize=(8, 6.5)) # Size of the figures.
heatmap = sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm",
                      cbar_kws= {"label":"spearman correlation"})

heatmap.set_title("Correlation heatmap")
plt.show()

# %%
# Anything closer 1 and -1 one really strong correlation, Anything close to 0 is very weak correlation.
books[(books['description'].isna()) |
      (books['num_pages'].isna()) |
      (books['average_rating'].isna()) |
      (books['published_year'].isna())
]
